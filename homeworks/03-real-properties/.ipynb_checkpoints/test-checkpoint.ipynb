# %%
g = Import["dolphins.gml", "Graph"];

# %%
Graph[g, 
 GraphLayout -> "SpringEmbedding", 
 VertexStyle -> Directive[Pink, EdgeForm[None]], 
 EdgeStyle -> Gray, 
 VertexSize -> Large, 
 PlotLabel -> Style["Spring Layout"]
]
# Out:
# Graph[<62>, <159>]

# %%
Graph[g, 
 GraphLayout -> "CircularEmbedding", 
 VertexStyle -> Directive[Pink, EdgeForm[None]], 
 EdgeStyle -> Gray, 
 VertexSize -> Large, 
 PlotLabel -> Style["Circular Layout"]
]
# Out:
# Graph[<62>, <159>]

# %%
Graph[g, 
 GraphLayout -> "SpiralEmbedding", 
 VertexStyle -> Directive[Pink, EdgeForm[None]], 
 EdgeStyle -> Gray, 
 VertexSize -> Automatic, 
 PlotLabel -> Style["Spiral Layout"]
]
# Out:
# Graph[<62>, <159>]

# %%
Graph[g, 
 GraphLayout -> "SpectralEmbedding", 
 VertexStyle -> Directive[Pink, EdgeForm[None]], 
 EdgeStyle -> Gray, 
 VertexSize -> Automatic, 
 PlotLabel -> Style["Spectral Layout"],
 ImageSize -> 800
]
# Out:
# Graph[<62>, <159>]

# %%
Graph[g, 
 GraphLayout -> "KamadaKawaiEmbedding", 
 VertexStyle -> Directive[Pink, EdgeForm[None]], 
 EdgeStyle -> Gray, 
 VertexSize -> Automatic, 
 PlotLabel -> Style["KamandaKawai Layout"],
 ImageSize -> 800
]
# Out:
# Graph[<62>, <159>]
