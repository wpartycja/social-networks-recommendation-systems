# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
from scipy.stats import linregress
from graph_utils import *


# G = nx.read_gml("dolphins.gml")
G = nx.barabasi_albert_graph(1_000, 30) # (1000, 3)

# %% [markdown]
# ## Ex. 1 (1 point + 1 utils.py ?)

# %% [markdown]
# Import the data, draw their histogram

# %%
draw_basic_histrogram(G)

# %% [markdown]
# ## Ex. 2

# %% [markdown]
# Correct the scale of the plot’s axes to double logarithmic

# %%
draw_log_scale_histogram(G)

# %% [markdown]
# ## Ex. 3

# %% [markdown]
# Apply logarithmic binning as well.

# %%
draw_log_scale_histogram(G, log_bin=True)

# %% [markdown]
# ## Ex. 4

# %% [markdown]
# Compute and draw the survival function.

# %%
draw_survival_func(G)
# binowane logarytmicznie

# %% [markdown]
# ##  Ex. 5

# %% [markdown]
# Which chart is the most readable? Which is most robust for the
# noise?

# %% [markdown]
# ## Ex. 6

# %%
print(f'alpha = {calculate_alpha(G)}')
# Out:
# alpha = 2.7831007338833675

# %% [markdown]
# ## Ex. 7

# %% [markdown]
# Compute (formula and value for our data) MLE estimator for `α` with a known `xmin` assuming following distribution

# %%
calculate_MLE_estimator(G)
# Out:
# Estimated alpha (MLE): 2.93

# %%
import powerlaw

degrees = [d for n, d in G.degree()]
fit = powerlaw.Fit(degrees, discrete=True)
alpha = fit.power_law.alpha 

print(alpha)
# Out:
# Calculating best minimal value for power law fit
# 2.8647446246889423
